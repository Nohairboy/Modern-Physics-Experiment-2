# %% [markdown]
# # 微波与铁磁共振实验

# %%
import pandas as pd
path = r'C:\Users\86136\OneDrive\Desktop\2025近物实验\Cyh\微波和铁磁共振\铁磁共振data.xlsx'
df = pd.read_excel(path, sheet_name='Sheet1')

import matplotlib.pyplot as plt
from matplotlib import rcParams

# 设置中文字体和负号正常显示
rcParams['font.sans-serif'] = ['SimHei']
rcParams['axes.unicode_minus'] = False

# %%
def get_data(x_col, y_col):
    
    x = df.values[:,x_col]
    x = x[~pd.isnull(x)]
    x = [x2 for x2 in x if isinstance(x2, (float, int))]
    print(x)

    y = df.values[:,y_col]
    y = y[~pd.isnull(y)]
    y = [val*1 for val in y if isinstance(val, (int, float))]
    print(y)

    return x, y

def my_plot(x, y, my_x_label, my_y_label, my_label='', my_title='', my_figsize=(10, 6)):
    plt.figure(figsize=my_figsize)
    plt.plot(x, y, marker='o', color='red', label=my_label)

    plt.title(my_title)
    plt.xlabel(my_x_label)
    plt.ylabel(my_y_label)

    plt.grid(True)
    plt.legend()
    plt.show()

# %% [markdown]
# ## 1.2.1

# %%
x2, y2 = get_data(x_col = 0, y_col = 1)
my_plot(x2, y2, my_x_label='$U$ (V)', my_y_label='$I$ (mA)', my_label='$I-U$ 曲线',
         my_title=r'体效应管在 0V-13V 的 $I-U$ 曲线', my_figsize=(10, 6))
# Out:
# [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9, 9.5, 10, 10.5, 11, 11.5, 12, 12.5, 13]
# [117, 224, 315, 389, 439, 465, 474, 442, 436, 429, 429, 428, 417, 417, 417, 419, 420, 422, 424, 404, 403, 401, 400, 399, 398, 397]

# %% [markdown]
# ## 1.2.2

# %%
x3, y3 = get_data(x_col = 3, y_col = 5)
my_plot(x3, y3, my_x_label='$U$ (V)', my_y_label='$f$ (MHz)', my_label='$f-U$ 曲线',
         my_title=r'体效应管在 10V-13V 的 $f-U$ 曲线', my_figsize=(10, 6))
# Out:
# [10.04, 10.43, 10.94, 11.19, 11.54, 11.92, 12.14, 12.41, 12.96]
# [8973, 8970, 8966, 8964, 8960, 8958, 8955, 8952, 8946]

# %% [markdown]
# ## 1.3

# %%
x4, y4 = get_data(x_col = 8, y_col = 9)
skp_indices = {9,10,len(x4)-2,len(x4)-3,len(x4)-4}

x4 = [val for i, val in enumerate(x4) if i not in skp_indices] 
y4 = [val for i, val in enumerate(y4) if i not in skp_indices]

my_plot(x4, y4, my_x_label='$f$ (MHz)', my_y_label='$I$ (mA)', my_label='$f-P$ 曲线',
         my_title=r'微波输出功率 $f-P$ 曲线', my_figsize=(10, 6))
# Out:
# [8.9, 8.918, 8.931, 8.949, 8.958, 8.978, 8.992, 9.002, 9.012, 8.992, 9.021, 9.045, 9.062, 9.098, 9.128, 9.145, 9.155, 9.172, 9.183, 9.152, 9.163, 9.18, 9.198]
# [26.5, 37, 45.5, 50.6, 60.5, 59.3, 71, 78, 84, 76, 75, 99, 130, 110, 99, 89, 77, 71, 67, 61, 51.5, 52.5, 54]

# %% [markdown]
# ## 2.2 观察传输式谐振腔谐振曲线

# %%
x5, y5 = get_data(x_col = 13, y_col = 14)
my_plot(x5, y5, my_x_label='$f$ (MHz)', my_y_label='检波示数', 
         my_title='检波示随微波频率的变化关系', my_figsize=(10, 6))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [9, 9.048, 9.053, 9.056, 9.058, 9.062, 9.064, 9.065, 9.068, 9.07, 9.072, 9.074, 9.076, 9.078, 9.081, 9.084, 9.086, 9.088, 9.13]
# [5, 6, 11, 19, 25, 47, 60, 67, 80, 76, 67, 54, 43, 30, 17, 10, 7, 6, 5]

# %% [markdown]
# ## 2.3 测量传输式谐振腔谐振曲线与品质因数

# %%
x6, y6 = get_data(x_col = 18, y_col = 19)
my_plot(x6, y6, my_x_label='$f$ (MHz)', my_y_label='$I$ ($\mu A$)', 
         my_title='传输式谐振腔谐振曲线', my_figsize=(10, 6))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [8.995, 9.032, 9.05, 9.058, 9.06, 9.062, 9.064, 9.065, 9.066, 9.067, 9.068, 9.07, 9.072, 9.073, 9.075, 9.077, 9.078, 9.08, 9.081, 9.083, 9.087, 9.09, 9.095, 9.099, 9.12]
# [0, 1, 3, 10.5, 16, 21, 30, 40, 51, 60, 71, 85, 90, 91, 89, 70, 51, 32, 23, 14, 6, 3.5, 2, 2, 0]

# %% [markdown]
# ## 2.6 用逐点法测量样品的共振曲线

# %%
x7, y7 = get_data(x_col = 22, y_col = 23)
my_plot(x7, y7, my_x_label='$B$ (mT)', my_y_label='$I$ ($\mu A$)', 
         my_title='多晶样品的共振曲线', my_figsize=(10, 6))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [148.90910000000002, 159.42710000000002, 164.68610000000004, 165.73790000000002, 166.78970000000004, 167.84150000000002, 168.36740000000003, 168.68294000000003, 168.99848000000003, 169.41920000000002, 169.94510000000002, 170.99690000000004, 171.52280000000002, 172.04870000000003, 172.57460000000003, 173.1005, 173.62640000000002, 174.15230000000003, 174.67820000000003, 175.2041, 175.73000000000002, 176.25590000000003, 176.78180000000003, 177.3077, 178.35950000000003, 179.4113, 180.46310000000003, 183.6185, 186.77390000000003, 190.98110000000003]
# [52, 51, 49.9, 49.8, 48, 45, 40, 36, 33, 28, 24, 16, 15, 17, 23, 28, 33, 38, 40.5, 42, 44.5, 47, 47.5, 48, 49, 50, 51, 52.1, 53.6, 54]

# %% [markdown]
# ## 2.7 用高斯计测量电磁铁电流与磁场强度的关系

# %%
x8, y8 = get_data(x_col = 25, y_col = 26)

skp_indice = {len(x8), len(x8)-1, len(x8)-2, len(x8)-3, len(x8)-4}

x8 = [val for i, val in enumerate(x8) if i not in skp_indice] 
y8 = [val for i, val in enumerate(y8) if i not in skp_indice]

import numpy as np
from sklearn.linear_model import LinearRegression

X_train = np.array(x8).reshape(len(x8), 1)  
Y_train = np.array(y8).reshape(len(y8), 1)  

lineModel = LinearRegression()
lineModel.fit(X_train, Y_train)

Y_predict = lineModel.predict(X_train)

#coef_是系数，intercept_是截距
k = lineModel.coef_[0]
b = lineModel.intercept_[0]
print("y=%.4f*x+%.4f" % (k,b))

#对回归模型进行评分，这里简单使用训练集进行评分，实际很多时候用其他的测试集进行评分
print("R2 = ", lineModel.score(X_train, Y_train))


plt.figure(figsize=(10,6))
plt.scatter(x8, y8, marker='o', color='red')
plt.plot(X_train, Y_predict, c="red")

plt.title('电磁铁电流与磁场强度的关系')
plt.xlabel('$I$ ($A$)')
plt.ylabel('$B$ ($mT$)')

plt.grid(True)
plt.legend()
plt.show()
# Out:
# C:\Users\86136\AppData\Local\Temp\ipykernel_18316\1089543462.py:22: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("y=%.4f*x+%.4f" % (k,b))
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [0, 0.011, 0.033, 0.044, 0.093, 0.125, 0.201, 0.27, 0.429, 0.641, 0.955, 1.125, 1.446, 1.692, 1.933, 2.116, 2.218, 2.452, 2.637, 2.743, 2.824]
# [0.64, 0.8, 11.6, 13.7, 22.4, 28.3, 43, 57, 89, 132, 198, 229, 291, 336, 377, 406, 421, 448, 467, 471, 478]
# y=192.2971*x+5.4550
# R2 =  0.9988231050422576

# %% [markdown]
# ## 2.8 计算样品的旋磁比γ、g因子和弛豫时间τ
